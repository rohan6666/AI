# %%
def AStar(startNode, stopNode):
    
    openSet = set([startNode])
    closeSet = set()
    dist = {}  # store distance from start node
    neighbour = {}  # Store adjacency nodes of all nodes
    
    dist[startNode] = 0
    neighbour[startNode] = None
    
    while len(openSet) > 0:
        currNode = None
        
        for v in openSet:
            if currNode is None or dist[v] + Heuristics(v) < dist[currNode] + Heuristics(currNode):
                currNode = v
        
        if currNode == stopNode or currNode not in graph:
            break
        else:
            for m, weight in graph[currNode]:
                if m not in openSet and m not in closeSet:
                    openSet.add(m)
                    neighbour[m] = currNode
                    dist[m] = dist[currNode] + weight
                else:
                    if dist[m] > dist[currNode] + weight:
                        dist[m] = dist[currNode] + weight
                        neighbour[m] = currNode
                        
                        if m in closeSet:
                            closeSet.remove(m)
                            openSet.add(m)
        
        openSet.remove(currNode)
        closeSet.add(currNode)
    
    if currNode is None:
        print('Path does not exist')
        return None
    
    if currNode == stopNode:
        path = []
        while neighbour[currNode] is not None:
            path.append(currNode)
            currNode = neighbour[currNode]
        path.append(startNode)
        path.reverse()
        print('Path Found: {}'.format(path))
        return path
    
    print('Path does not exist')
    return None

def Heuristics(n):
    hDist = {
        'A': 11,
        'B': 6,
        'C': 99,
        'D': 1,
        'E': 7,
        'G': 0,
    }
    return hDist[n]

graph = {
    'A': [('B', 2), ('E', 3)],
    'B': [('C', 1), ('G', 9)],
    'C': None,
    'E': [('D', 6)],
    'D': [('G', 1)]
}

AStar('A', 'G')
# Out:
# Path Found: ['A', 'E', 'D', 'G']
# ['A', 'E', 'D', 'G']

# %%
def AStar(st, en):
    openSet = set([st])
    closeSet = set()
    neighbour = {}
    dist = {}
    
    neighbour[st] = None
    dist[st] = 0
    
    while len(openSet) > 0:
        curr = None
        
        for v in openSet:
            if curr is None or dist[v] + Hue(v) < dist[curr] + Hue(curr):
                curr = v
        
        if curr == en or curr not in graph:
            break
        else:
            for m, weight in graph[curr]:
                if m not in openSet and m not in closeSet:
                    openSet.add(m)
                    dist[m] = dist[curr] + weight
                    neighbour[m] = curr
                else:
                    if dist[m] > dist[curr] + weight:
                        dist[m] = dist[curr] + weight
                        neighbour[m] = curr
                        
                        if m in closeSet:
                            closeSet.remove(m)
                            openSet.add(m)
                            
            openSet.remove(curr)
            closeSet.add(curr)
            
    if curr is None:
        print("Path Not Found")
        return None
            
    if curr == en:
        path = []
        while neighbour[curr] is not None:
            path.append(curr)
            curr = neighbour[curr]
                    
        path.append(st)
        path.reverse()
        print('Path Found: {}'.format(path))
        return path
    print("Not Found")
    return None
            
                
            
    
def Hue(n):
    hur = {
        'A' : 11,
        'B' : 6,
        'C' : 99,
        'D' : 1,
        'E' : 6,
        'G' : 0,
    }
    
    return hur[n]


graph = {
    'A': [('B', 2), ('E', 3)],
    'B': [('C', 1), ('G', 9)],
    'C': None,
    'E': [('D', 6)],
    'D': [('G', 1)]
}

AStar('A', 'G')
# Out:
# Path Found: ['A', 'E', 'D', 'G']
# ['A', 'E', 'D', 'G']
